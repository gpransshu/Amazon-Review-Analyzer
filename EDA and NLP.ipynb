# %% [markdown]
# ## Importing Libraries and Reading Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("ReviewData.xlsx")

# %%
df1 = pd.read_excel("RatingData.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  1.0 out of 5 stars\nIt is a total waste of money!
# 1           1  1.0 out of 5 stars\nI am or sure if the produc...
# 2           2                             1.0 out of 5 stars\n👎🏻
# 3           3  1.0 out of 5 stars\nHeating and poor performan...
# 4           4             1.0 out of 5 stars\nscratch on display
#
#                rating                                 date  \
# 0  1.0 out of 5 stars  Reviewed in India on 7 October 2023
# 1  1.0 out of 5 stars     Reviewed in India on 22 May 2024
# 2  1.0 out of 5 stars   Reviewed in India on 25 April 2024
# 3  1.0 out of 5 stars     Reviewed in India on 10 May 2024
# 4  1.0 out of 5 stars     Reviewed in India on 13 May 2024
#
#                                                 body  \
# 0  Things to remember before you buy an Iphone -1...
# 1  When ever I am speaking I have problem with sp...
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0 star_rating  ratings  reviews
# 0           0      1 star     1347      435
# 1           1      2 star      317       95
# 2           2      3 star      773      124
# 3           3      4 star     3919      442
# 4           4      5 star    20639     2419

# %% [markdown]
# ## Data Cleaning

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df1 = df1.drop(df1.columns[0], axis=1)

# %%
df.head()
# Out:
#                                                title              rating  \
# 0  1.0 out of 5 stars\nIt is a total waste of money!  1.0 out of 5 stars
# 1  1.0 out of 5 stars\nI am or sure if the produc...  1.0 out of 5 stars
# 2                             1.0 out of 5 stars\n👎🏻  1.0 out of 5 stars
# 3  1.0 out of 5 stars\nHeating and poor performan...  1.0 out of 5 stars
# 4             1.0 out of 5 stars\nscratch on display  1.0 out of 5 stars
#
#                                   date  \
# 0  Reviewed in India on 7 October 2023
# 1     Reviewed in India on 22 May 2024
# 2   Reviewed in India on 25 April 2024
# 3     Reviewed in India on 10 May 2024
# 4     Reviewed in India on 13 May 2024
#
#                                                 body  \
# 0  Things to remember before you buy an Iphone -1...
# 1  When ever I am speaking I have problem with sp...
# 2  Bekr phone hai iPhone 13 bhut slow hai bettery...
# 3  Heating , sounds not goodOnly name and brand p...
# ...

# %%
df1.head()
# Out:
#   star_rating  ratings  reviews
# 0      1 star     1347      435
# 1      2 star      317       95
# 2      3 star      773      124
# 3      4 star     3919      442
# 4      5 star    20639     2419

# %%
df.isnull().sum()
# Out:
# title       0
# rating      0
# date        0
# body       15
# details     0
# dtype: int64

# %%
df[df['title']=='']
# Out:
# Empty DataFrame
# Columns: [title, rating, date, body, details]
# Index: []

# %%
df.dropna(axis=0, inplace=True)

# %%
# Remove newline character '\n' from each string in the 'title' column
df['title'] = df['title'].str.split('\n').str[1]
#df['body'] = df['body'].str.split('\n').str[1]
df['date'] = df['date'].str.split('on ').str[1]

# %%
# Extract only the first number from the 'rating' column
df['rating'] = df['rating'].str.split(' ', expand=True)[0]


# Convert the 'rating' column to float
df['rating'] = df['rating'].astype(float)

# Convert the 'rating' column to integer
df['rating'] = df['rating'].astype(int)

# %%
df['date'] = pd.to_datetime(df['date'], format='%d %B %Y')

# %%
# Split the 'details' column into 'colour' and 'size' columns
df[['colour', 'size']] = df['details'].str.split('Size:', expand=True)

# Strip any leading or trailing whitespace
df['colour'] = df['colour'].str.strip()
df['size'] = df['size'].str.strip()

df.drop(columns=['details'], inplace=True)

# %%
# Remove rows where 'body' contains ''
df = df[df['body'] != '']

# %%
df
# Out:
#                                                  title  rating       date  \
# 0                        It is a total waste of money!       1 2023-10-07
# 1    I am or sure if the product is in right condition       1 2024-05-22
# 2                                                   👎🏻       1 2024-04-25
# 3    Heating and poor performance, slow system as well       1 2024-05-10
# 4                                   scratch on display       1 2024-05-13
# ..                                                 ...     ...        ...
# 489                                               Good       5 2024-03-30
# 490                                      Always a king       5 2024-03-20
# 491         Wholesome bundle of worthiness - iPhone 13       5 2024-03-01
# 493                                        Majha aagya       5 2024-03-31
# 494                  Fantastic First iPhone Experience       5 2024-03-11
#
#                                                   body             colour  \
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [title, rating, date, body, colour, size]
# Index: []

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, 0 to 494
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   480 non-null    object
#  1   rating  480 non-null    int32
#  2   date    480 non-null    datetime64[ns]
#  3   body    480 non-null    object
#  4   colour  480 non-null    object
#  5   size    480 non-null    object
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 24.4+ KB

# %%
df['rating'].value_counts()
# Out:
# rating
# 1    100
# 3     97
# 4     96
# 2     94
# 5     93
# Name: count, dtype: int64

# %%
#do pivot or group by for below and make bar graph for it or match it with ratings count

# %%
df[['colour','size']].value_counts()
# Out:
# colour                 size
# Colour: Starlight      128 GB    114
# Colour: Midnight       128 GB     99
# Colour: Blue           128 GB     95
# Colour: Green          128 GB     50
# Colour: Pink           128 GB     49
# Colour: (PRODUCT) RED  128 GB     27
# Colour: Starlight      256 GB      9
# Colour: Midnight       256 GB      7
# Colour: Blue           256 GB      6
# Colour: Pink           256 GB      6
#                        512 GB      5
# Colour: (PRODUCT) RED  512 GB      4
# Colour: Green          256 GB      4
# Colour: Blue           512 GB      2
# Colour: Midnight       512 GB      2
# Colour: (PRODUCT) RED  256 GB      1
# Name: count, dtype: int64

# %%
df.to_excel("CleanedReviewData.xlsx")

# %%
df = pd.read_excel("CleanedReviewData.xlsx")

# %%
#import emoji

# %%
#def convert_emojis(text):
#    return emoji.demojize(text, delimiters=(":", ":"))

# %%
# Apply the function to the 'title' and 'body' columns
#df['title'] = df['title'].apply(convert_emojis)
#df['body'] = df['body'].apply(convert_emojis)

# %%
from deep_translator import GoogleTranslator

# %%
df['title'] = [GoogleTranslator(source='auto', target='en').translate(title) for title in df['title']]

# %%
df['body'] = [GoogleTranslator(source='auto', target='en').translate(title) for title in df['body']]

# %%
df['title']
# Out:
# 0                          It is a total waste of money!
# 1      I am or sure if the product is in right condition
# 2                                                   None
# 3      Heating and poor performance, slow system as well
# 4                                     scratch on display
#                              ...
# 475                                                 Good
# 476                                        Always a king
# 477           Wholesome bundle of worthiness - iPhone 13
# 478                                          Majha aagya
# 479                    Fantastic First iPhone Experience
# Name: title, Length: 480, dtype: object

# %%
from transformers import pipeline
#specific_model = pipeline(model="cardiffnlp/twitter-roberta-base-sentiment-latest")

# %%
df[df.isna().any(axis=1)]
# Out:
#      Unnamed: 0        title  rating       date  \
# 2             2         None       1 2024-04-25
# 118         118  bad speaker       2 2023-12-20
# 336         341         None       4 2024-02-06
# 398         406      Awesome       5 2023-10-08
# 417         426         None       5 2024-05-19
#
#                                                   body                 colour  \
# 2    Bekr phone hai iPhone 13 bhut slow hai bettery...      Colour: Starlight
# 118                                               None  Colour: (PRODUCT) RED
# 336                                             Good 👍       Colour: Midnight
# 398                                               None      Colour: Starlight
# 417  Battery 🪫 health decreases very quickly94% in ...      Colour: Starlight
#
#        size
# 2    128 GB
# 118  256 GB
# 336  128 GB
# 398  128 GB
# 417  128 GB

# %%
df.dropna(axis=0, inplace=True)

# %%
#tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased-distilled-squad")

# %% [markdown]
# sb = []
# counter = 0
# for b in df['body']:
#     print(counter)
#     #tokenized_sentence = tokenizer.encode(b, padding=True, truncation=True,max_length=50, add_special_tokens = True)
#     sb.append(sentiment_pipeline(b))
#     counter+= 1

# %%
df
# Out:
#      Unnamed: 0                                              title  rating  \
# 0             0                      It is a total waste of money!       1
# 1             1  I am or sure if the product is in right condition       1
# 3             3  Heating and poor performance, slow system as well       1
# 4             4                                 scratch on display       1
# 5             5                                   Charging problam       1
# ..          ...                                                ...     ...
# 475         489                                               Good       5
# 476         490                                      Always a king       5
# 477         491         Wholesome bundle of worthiness - iPhone 13       5
# 478         493                                        Majha aagya       5
# 479         494                  Fantastic First iPhone Experience       5
#
#           date                                               body  \
# ...

# %%
#df[['sentiment_body','rating']].value_counts()

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax

# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

def get_sentiment(text):
    MODEL = "cardiffnlp/twitter-roberta-base-sentiment-latest"
    tokenizer = AutoTokenizer.from_pretrained(MODEL)
    config = AutoConfig.from_pretrained(MODEL)
    model = AutoModelForSequenceClassification.from_pretrained(MODEL)

    text = preprocess(text)
    encoded_input = tokenizer(text, return_tensors='pt',truncation=True, padding=True, max_length=512)
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    # Get the top label and its score
    top_index = np.argmax(scores)
    top_label = config.id2label[top_index]
    #top_score = scores[top_index]

    return top_label#, np.round(float(top_score), 4)

# %%
from transformers import logging

logging.set_verbosity_warning()

# %%
df['sentiment'] = df['body'].apply(get_sentiment)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
df
# Out:
#      Unnamed: 0                                              title  rating  \
# 0             0                      It is a total waste of money!       1
# 1             1  I am or sure if the product is in right condition       1
# 3             3  Heating and poor performance, slow system as well       1
# 4             4                                 scratch on display       1
# 5             5                                   Charging problam       1
# ..          ...                                                ...     ...
# 475         489                                               Good       5
# 476         490                                      Always a king       5
# 477         491         Wholesome bundle of worthiness - iPhone 13       5
# 478         493                                        Majha aagya       5
# 479         494                  Fantastic First iPhone Experience       5
#
#           date                                               body  \
# ...

# %%
df.to_excel("FinalData.xlsx")
